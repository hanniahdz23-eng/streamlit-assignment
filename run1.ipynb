# %%
import streamlit as st

# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run streamex.py --server.headless true
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://10.22.201.186:8502
#   External URL: http://131.178.102.200:8502
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# 2025-11-13 14:41:36.671 Uncaught app execution
# Traceback (most recent call last):
#   File "/Users/hanniahdz58/Desktop/Streamlit/venv/lib/python3.13/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 129, in exec_func_with_error_handling
#     result = func()
#   File "/Users/hanniahdz58/Desktop/Streamlit/venv/lib/python3.13/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 669, in code_to_exec
#     exec(code, module.__dict__)  # noqa: S102
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hanniahdz58/Desktop/Streamlit/streamex.py", line 93, in <module>
#     seller_name = vendor_data["NAME"].iloc[0]
#                   ^^^^^^^^^^^
# ...
